# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
# %run util.ipynb

# %%
class LogisticModel(object):
    def __init__(self):
        pass
    
    def fit(self,X,Y,learning_rate=10e-7,reg=0,epochs=120000,show_fig=False):
        X,Y = shuffle(X,Y)
        Xvalid, Yvalid = X[-1000:], Y[-1000:]
        X,Y = X[:-1000], Y[:-1000]
        
        N,D = X.shape
        self.W = np.random.randn(D) / np.sqrt(D)
        self.b = 0
        
        cost = []
        best_validation_error = 1
        
        for i in range(epochs):
            pY = self.forward(X)
            
            # gradient descent to train weights
            self.W -= learning_rate*(X.T.dot(pY-Y) + reg*self.W)
            self.b -= learning_rate*((pY-Y).sum() + reg*self.b)
            
            if i%100==0:
                pYvalid = self.forward(Xvalid)
                c = sigmoid_cost(Yvalid,pYvalid)
                cost.append(c)
                e = error_rate(Yvalid,np.round(pYvalid))
                print(f"i: {i}, cost: {c}, error: {e}")
                
                
                if e < best_validation_error:
                    best_validation_error = e
            
                print("best validation error : ", best_validation_error)
            
    def forward(self,X):
        return sigmoid(X.dot(self.W) + self.b)
    
    def predict(self,X):
        pY = self.forward(X)
        return np.round(pY)
    
    def score(self,X,Y):
        prediction = self.predict(X)
        return 1-error_rate(Y,predictions)
    
def main():
    X,Y = getBinaryData()

    X0 = X[Y==0,:]
    X1 = X[Y==1,:]
    X1 = np.repeat(X1,9,axis=0)
    X = np.vstack([X0,X1])
    Y = np.array([0]*len(X0) + [1]*len(X1))

    model = LogisticModel()
    model.fit(X,Y,show_fig=True)
    model.score(X,Y)

if __name__ == '__main__':
    main()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# i: 0, cost: 738.1279292377867, error: 0.525
# best validation error :  0.525
# i: 100, cost: 668.9587535210303, error: 0.376
# best validation error :  0.376
# i: 200, cost: 652.6678019054482, error: 0.358
# best validation error :  0.358
# i: 300, cost: 642.9645820361246, error: 0.351
# best validation error :  0.351
# i: 400, cost: 635.9835604847453, error: 0.354
# best validation error :  0.351
# i: 500, cost: 630.3881622195611, error: 0.352
# best validation error :  0.351
# i: 600, cost: 625.6137464919038, error: 0.346
# best validation error :  0.346
# i: 700, cost: 621.3833500651983, error: 0.343
# best validation error :  0.343
# i: 800, cost: 617.5445200172367, error: 0.344
# best validation error :  0.343
# i: 900, cost: 614.0055421160098, error: 0.335
# best validation error :  0.335
# i: 1000, cost: 610.7072620840361, error: 0.323
# best validation error :  0.323
# i: 1100, cost: 607.6093015185529, error: 0.32
# best validation error :  0.32
# i: 1200, cost: 604.6827440161034, error: 0.316
# best validation error :  0.316
# i: 1300, cost: 601.906000938818, error: 0.307
# best validation error :  0.307
# i: 1400, cost: 599.2623567404178, error: 0.306
# best validation error :  0.306
# i: 1500, cost: 596.7384532649888, error: 0.3
# best validation error :  0.3
# i: 1600, cost: 594.3233227629196, error: 0.298
# best validation error :  0.298
# i: 1700, cost: 592.0077530337443, error: 0.296
# best validation error :  0.296
# i: 1800, cost: 589.7838594676343, error: 0.293
# best validation error :  0.293
# i: 1900, cost: 587.6447891782916, error: 0.289
# best validation error :  0.289
# i: 2000, cost: 585.5845113333905, error: 0.286
# best validation error :  0.286
# i: 2100, cost: 583.5976648895157, error: 0.286
# best validation error :  0.286
# i: 2200, cost: 581.6794453128326, error: 0.285
# best validation error :  0.285
# i: 2300, cost: 579.8255182957887, error: 0.279
# best validation error :  0.279
# i: 2400, cost: 578.0319525376963, error: 0.279
# best validation error :  0.279
# i: 2500, cost: 576.2951662592757, error: 0.28
# best validation error :  0.279
# i: 2600, cost: 574.6118838143304, error: 0.278
# best validation error :  0.278
# i: 2700, cost: 572.9790998780984, error: 0.276
# best validation error :  0.276
# i: 2800, cost: 571.3940494372538, error: 0.274
# best validation error :  0.274
# i: 2900, cost: 569.8541823104961, error: 0.275
# best validation error :  0.274
# i: 3000, cost: 568.357141273616, error: 0.277
# best validation error :  0.274
# i: 3100, cost: 566.9007431020791, error: 0.276
# best validation error :  0.274
# i: 3200, cost: 565.4829620122136, error: 0.274
# best validation error :  0.274
# i: 3300, cost: 564.1019151018362, error: 0.273
# best validation error :  0.273
# i: 3400, cost: 562.7558494777863, error: 0.273
# best validation error :  0.273
# i: 3500, cost: 561.4431308215044, error: 0.271
# best validation error :  0.271
# i: 3600, cost: 560.1622331913545, error: 0.271
# best validation error :  0.271
# i: 3700, cost: 558.9117298965291, error: 0.27
# best validation error :  0.27
# i: 3800, cost: 557.6902853052895, error: 0.271
# best validation error :  0.27
# i: 3900, cost: 556.4966474722191, error: 0.27
# best validation error :  0.27
# i: 4000, cost: 555.3296414866542, error: 0.27
# best validation error :  0.27
# i: 4100, cost: 554.1881634586036, error: 0.268
# best validation error :  0.268
# i: 4200, cost: 553.0711750700802, error: 0.269
# best validation error :  0.268
# i: 4300, cost: 551.9776986293873, error: 0.266
# best validation error :  0.266
# i: 4400, cost: 550.9068125739769, error: 0.266
# best validation error :  0.266
# i: 4500, cost: 549.8576473743237, error: 0.266
# best validation error :  0.266
# i: 4600, cost: 548.8293817970709, error: 0.266
# best validation error :  0.266
# i: 4700, cost: 547.8212394906955, error: 0.265
# best validation error :  0.265
# i: 4800, cost: 546.8324858612435, error: 0.261
# best validation error :  0.261
# i: 4900, cost: 545.8624252094129, error: 0.26
# best validation error :  0.26
# i: 5000, cost: 544.9103981035003, error: 0.261
# best validation error :  0.26
# i: 5100, cost: 543.9757789655654, error: 0.259
# best validation error :  0.259
# i: 5200, cost: 543.0579738506347, error: 0.259
# best validation error :  0.259
# i: 5300, cost: 542.1564184009494, error: 0.259
# best validation error :  0.259
# i: 5400, cost: 541.2705759591659, error: 0.258
# best validation error :  0.258
# i: 5500, cost: 540.3999358261078, error: 0.258
# best validation error :  0.258
# i: 5600, cost: 539.5440116501578, error: 0.257
# best validation error :  0.257
# i: 5700, cost: 538.702339936686, error: 0.257
# best validation error :  0.257
# i: 5800, cost: 537.8744786670921, error: 0.256
# best validation error :  0.256
# i: 5900, cost: 537.060006018059, error: 0.256
# best validation error :  0.256
# i: 6000, cost: 536.2585191725477, error: 0.256
# best validation error :  0.256
# i: 6100, cost: 535.4696332148789, error: 0.255
# best validation error :  0.255
# i: 6200, cost: 534.6929801029726, error: 0.252
# best validation error :  0.252
# i: 6300, cost: 533.9282077114801, error: 0.252
# best validation error :  0.252
# i: 6400, cost: 533.1749789401158, error: 0.252
# best validation error :  0.252
# i: 6500, cost: 532.4329708820223, error: 0.252
# best validation error :  0.252
# i: 6600, cost: 531.7018740474755, error: 0.253
# best validation error :  0.252
# i: 6700, cost: 530.9813916386462, error: 0.252
# best validation error :  0.252
# i: 6800, cost: 530.2712388715247, error: 0.251
# best validation error :  0.251
# i: 6900, cost: 529.5711423414459, error: 0.252
# best validation error :  0.251
# i: 7000, cost: 528.880839428964, error: 0.251
# best validation error :  0.251
# i: 7100, cost: 528.2000777431011, error: 0.251
# best validation error :  0.251
# i: 7200, cost: 527.528614599248, error: 0.25
# best validation error :  0.25
# i: 7300, cost: 526.8662165292131, error: 0.251
# best validation error :  0.25
# i: 7400, cost: 526.212658821133, error: 0.25
# best validation error :  0.25
# i: 7500, cost: 525.5677250871329, error: 0.249
# best validation error :  0.249
# i: 7600, cost: 524.931206856803, error: 0.247
# best validation error :  0.247
# i: 7700, cost: 524.3029031947052, error: 0.248
# best validation error :  0.247
# i: 7800, cost: 523.6826203402663, error: 0.248
# best validation error :  0.247
# i: 7900, cost: 523.0701713685437, error: 0.248
# best validation error :  0.247
# i: 8000, cost: 522.4653758704613, error: 0.247
# best validation error :  0.247
# i: 8100, cost: 521.8680596512254, error: 0.247
# best validation error :  0.247
# i: 8200, cost: 521.2780544457225, error: 0.247
# best validation error :  0.247
# i: 8300, cost: 520.6951976497943, error: 0.247
# best validation error :  0.247
# i: 8400, cost: 520.1193320663625, error: 0.246
# best validation error :  0.246
# i: 8500, cost: 519.5503056654562, error: 0.246
# best validation error :  0.246
# i: 8600, cost: 518.9879713572576, error: 0.245
# best validation error :  0.245
# i: 8700, cost: 518.4321867773492, error: 0.245
# best validation error :  0.245
# i: 8800, cost: 517.8828140834021, error: 0.244
# best validation error :  0.244
# i: 8900, cost: 517.3397197625986, error: 0.244
# best validation error :  0.244
# i: 9000, cost: 516.8027744491319, error: 0.243
# best validation error :  0.243
# i: 9100, cost: 516.271852751169, error: 0.243
# best validation error :  0.243
# i: 9200, cost: 515.7468330867111, error: 0.242
# best validation error :  0.242
# i: 9300, cost: 515.2275975278142, error: 0.242
# best validation error :  0.242
# i: 9400, cost: 514.7140316526792, error: 0.241
# best validation error :  0.241
# i: 9500, cost: 514.2060244051476, error: 0.24
# best validation error :  0.24
# i: 9600, cost: 513.7034679611684, error: 0.24
# best validation error :  0.24
# i: 9700, cost: 513.2062576018377, error: 0.239
# best validation error :  0.239
# i: 9800, cost: 512.7142915926293, error: 0.238
# best validation error :  0.238
# i: 9900, cost: 512.2274710684661, error: 0.239
# best validation error :  0.238
# i: 10000, cost: 511.7456999243004, error: 0.237
# best validation error :  0.237
# i: 10100, cost: 511.26888471089796, error: 0.237
# best validation error :  0.237
# i: 10200, cost: 510.79693453553, error: 0.236
# best validation error :  0.236
# i: 10300, cost: 510.32976096730806, error: 0.236
# best validation error :  0.236
# i: 10400, cost: 509.86727794690364, error: 0.235
# best validation error :  0.235
# i: 10500, cost: 509.40940170041506, error: 0.235
# best validation error :  0.235
# i: 10600, cost: 508.9560506571576, error: 0.235
# best validation error :  0.235
# i: 10700, cost: 508.5071453711664, error: 0.234
# best validation error :  0.234
# i: 10800, cost: 508.062608446215, error: 0.235
# best validation error :  0.234
# i: 10900, cost: 507.6223644641628, error: 0.235
# best validation error :  0.234
# i: 11000, cost: 507.1863399164581, error: 0.235
# best validation error :  0.234
# i: 11100, cost: 506.7544631386321, error: 0.235
# best validation error :  0.234
# i: 11200, cost: 506.3266642476284, error: 0.234
# best validation error :  0.234
